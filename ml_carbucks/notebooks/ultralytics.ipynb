# %%
from ultralytics import YOLO

model = YOLO("yolo11l.pt")

data_yaml = "/home/bachelor/ml-carbucks/tests/data/instances_demo_singular_curated.yaml"

model.train(
    epochs=10,
    data=data_yaml
)


results = model.val(
    data=data_yaml
)

print(results.results_dict)

# %%
from ultralytics import RTDETR

model = RTDETR("rtdetr-l.pt")

data_yaml = "/home/bachelor/ml-carbucks/tests/data/instances_demo_singular_curated.yaml"

model.train(
    epochs=100,
    data=data_yaml
)


results = model.val(
    data=data_yaml
)

print(results.results_dict)
