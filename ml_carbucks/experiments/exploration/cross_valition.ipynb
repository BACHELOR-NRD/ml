# %%
# Reload the module to pick up changes
import importlib
import ml_carbucks.utils.cross_validation
importlib.reload(ml_carbucks.utils.cross_validation)
# Out:
# <module 'ml_carbucks.utils.cross_validation' from '/home/bachelor/ml-carbucks/ml_carbucks/utils/cross_validation.py'>

# %%
from ml_carbucks.utils.cross_validation import stratified_cross_valitation
from pathlib import Path

hyper_results_path = Path('/home/bachelor/ml-carbucks/results/optuna/hyper_20251110_202446/results_RtdetrUltralyticsAdapter.json')
results_directory = Path('/home/bachelor/ml-carbucks/results/cross_validation')

results = stratified_cross_valitation(
    hyper_results=hyper_results_path, 
    results_dir=results_directory
)
# Out:
# INFO ml_carbucks.utils.cross_validation 23:37:21 | Starting stratified cross-validation
# 5
# INFO ml_carbucks.utils.cross_validation 23:37:21 | Processing fold 1
# INFO ml_carbucks.utils.cross_validation 23:37:21 | Hyperparameters for fold 1: {'batch_size': 32, 'epochs': 14, 'img_size': 384, 'lr': 0.00024406853367265458, 'momentum': 0.941920609133938, 'optimizer': 'NAdam', 'weight_decay': 0.00017052972123891876}
# INFO ml_carbucks.utils.cross_validation 23:37:21 | training dataset: [(PosixPath('/home/bachelor/ml-carbucks/data/carbucks_crossval_folds/fold_1/images/train'), PosixPath('/home/bachelor/ml-carbucks/data/carbucks_crossval_folds/fold_1/annotations_train.json'))]
# INFO ml_carbucks.utils.cross_validation 23:37:21 | validation dataset: [(PosixPath('/home/bachelor/ml-carbucks/data/carbucks_crossval_folds/fold_1/images/val'), PosixPath('/home/bachelor/ml-carbucks/data/carbucks_crossval_folds/fold_1/annotations_val.json'))]
# ...
