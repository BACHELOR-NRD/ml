# %%
from ml_carbucks.utils.inference import plot_img_pred


plot_img_pred("/home/bachelor/ml-carbucks/data/car_dd/images/test/002908.jpg", [[
                197.38000000000002,
                239.10982850000002,
                182.66,
                260.079975
            ]], coords="xywh")
plot_img_pred("/home/bachelor/ml-carbucks/data/car_dd/images/test/002908.jpg", [[ 76.5151,  63.1616, 159.7407, 121.6128]], coords="xyxy")
plot_img_pred("/home/bachelor/ml-carbucks/data/car_dd/images/test/002908.jpg", [[ 63.1616,  76.5151, 121.6128, 159.7407]], coords="xyxy")
